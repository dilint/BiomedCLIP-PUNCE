# %% [markdown]
# # 生成w3标注

# %%
import os
import random
import json

DATA_ROOT = "D:/Dataset/"
config_name = '../../settings/environment.json'
if os.path.exists(config_name):
    with open(config_name, 'r') as file:
        info = json.load(file)
        DATA_ROOT = info["TCT_DATA_ROOT"]

input_dir = DATA_ROOT+'TCT-NGC-2023/base-data/'
# input_dir = DATA_ROOT+'TCT-NGC-2023/'
output_dir = DATA_ROOT+'TCT-NGC-2023/annotations/w3/'

# NILM对应1，POSITIVE对应0
sub_dirs = ['Unannotated_KSJ/Unannotated-KSJ-TCTNGC-NILM/', 
         'Unannotated_KSJ/Unannotated-KSJ-TCTNGC-POS/',
         'Unannotated_XIMEA/Unannotated-XIMEA-TCTNGC-NILM/',
         'Unannotated_XIMEA/Unannotated-XIMEA-TCTNGC-POS/']
labels = [1,
          -1,
          1,
          -1]


def get_all_wsi(input_dir, sub_dirs, labels):
    """get all wsi names, not directories"""
    wsi_set = set()
    for i, sub_dir in enumerate(sub_dirs):
        for wsi_dir in os.listdir(input_dir+sub_dir):
            item = (wsi_dir, labels[i])
            wsi_set.add(item)

    return wsi_set

def split_w3_dataset(wsi_set, output_dir):
    """split wsi_set and save to annotation files"""
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)

    # 打乱图片文件列表
    wsi_set = list(wsi_set)
    random.shuffle(wsi_set)
 
    # 计算训练、验证和测试集的数量
    num_wsi = len(wsi_set)
    num_train = int(0.8 * num_wsi)
    num_val = int(0.1 * num_wsi)
    
    # 划分数据集并保存到相应文件
    with open(os.path.join(output_dir, 'train.txt'), 'w') as train_file:
        for wsi_name, category in wsi_set[:num_train]:
            train_file.write(f"{wsi_name} {category}\n")

    with open(os.path.join(output_dir, 'val.txt'), 'w') as val_file:
        for wsi_name, category in wsi_set[num_train:num_train + num_val]:
            val_file.write(f"{wsi_name} {category}\n")

    with open(os.path.join(output_dir, 'test.txt'), 'w') as test_file:
        for wsi_name, category in wsi_set[num_train + num_val:]:
            test_file.write(f"{wsi_name} {category}\n")
    print("W3 for TCT-NGC-2023 split and saved successfully.")

def main():
    # 获取所有wsi的唯一标识
    wsi_set = get_all_wsi(input_dir, sub_dirs, labels)
    # 随机划分
    split_w3_dataset(wsi_set, output_dir)

main()
# Out:
# W3 for TCT-NGC-2023 split and saved successfully.

# %% [markdown]
# # 查看w3标注信息

# %%
import os
import numpy as np
import json

DATA_ROOT = "D:/Dataset/"
config_name = '../../settings/environment.json'
if os.path.exists(config_name):
    with open(config_name, 'r') as file:
        info = json.load(file)
        DATA_ROOT = info["TCT_DATA_ROOT"]

ann_dir = DATA_ROOT+'TCT-NGC-2023/annotations/w3/'
files=['train.txt', 'val.txt', 'test.txt']

def info_ann(file_name):
    print(f"{file_name}中的各类WSI数量如下：")
    items = []
    with open(ann_dir+file_name, 'r') as file:
        for line in file:
            items.append(line.strip().split())
    
    labels = [int(data[1]) for data in items]
    max_label = max(labels)
    counts = np.zeros(max_label+2, dtype=np.uint16)
    
    # 统计标注为 -1 和 1 的个数
    for item in items:
        label = int(item[1])
        counts[label] += 1

    # 输出统计结果
    for i, count in enumerate(counts):
        if i == max_label+1:
            print('类别{:>2}: {:>5}'.format(-1, count))
        else:
            print('类别{:>2}: {:>5}'.format(i, count))
    print('全部  : {:>5}'.format(sum(counts)))
    return sum(counts)

def main():
    sum_all = 0    
    for file in files:
        sum_all += info_ann(file)
    print("  ")
    print('总和  : {:>5}'.format(sum_all))
main()
# Out:
# train.txt中的各类WSI数量如下：
# 类别 0:     0
# 类别 1:   392
# 类别-1:   376
# 全部  :   768
# val.txt中的各类WSI数量如下：
# 类别 0:     0
# 类别 1:    55
# 类别-1:    41
# 全部  :    96
# test.txt中的各类WSI数量如下：
# 类别 0:     0
# 类别 1:    52
# 类别-1:    45
# 全部  :    97
#
# 总和  :   961

# %% [markdown]
# # 构建w1数据集标注

# %%
import os
import json

# **所有路径都不要使用单个反斜杠
# Benign 对应 1，malignant 对应 0
def main():
    """主函数"""
    
    # 获取根路径
    DATA_ROOT = "D:/Dataset/"
    config_name = '../../settings/environment.json'
    if os.path.exists(config_name):
        with open(config_name, 'r') as file:
            info = json.load(file)
            DATA_ROOT = info["TCT_DATA_ROOT"]
    
    # 定义各种路径
    input_dir = DATA_ROOT+'TCT-NGC-2023/base-data/'
    # input_dir = DATA_ROOT+'TCT-NGC-2023/'
    w3_dir = DATA_ROOT+'TCT-NGC-2023/annotations/w3/'
    output_dir = DATA_ROOT+'TCT-NGC-2023/annotations/w1/'

    # NILM对应1，POSITIVE对应0
    sub_dirs = ['Unannotated_KSJ/Unannotated-KSJ-TCTNGC-NILM/', 
            'Unannotated_KSJ/Unannotated-KSJ-TCTNGC-POS/',
            'Unannotated_XIMEA/Unannotated-XIMEA-TCTNGC-NILM/',
            'Unannotated_XIMEA/Unannotated-XIMEA-TCTNGC-POS/']
    labels = [1,
            -1,
            1,
            -1]
    ann_files=['train.txt', 'val.txt', 'test.txt']
    
    # 读取w3标注的三个子集的wsi信息
    wsi_partitions = list()
    for file_name in ann_files:
        wsi_part = list()
        # 读取一个文件 比如'train.txt'
        with open(os.path.join(w3_dir, file_name)) as file:
            for line in file:
                line = line.split()
                wsi_part.append(line[0])
        wsi_partitions.append(wsi_part)

    # 删除原本的标注信息
    for ann_file in ann_files:
        if os.path.exists(output_dir + ann_file):
            os.remove(output_dir + ann_file)

    # 将三个标注集对应的图片集合路径加入w1标注集
    for i, sub_dir in enumerate(sub_dirs):
        for wsi_name in os.listdir(input_dir + sub_dir):
            if wsi_name in wsi_partitions[0]:
                write_files_to_ann(input_dir, input_dir + sub_dir + wsi_name, labels[i], output_dir, 'train.txt')
            elif wsi_name in wsi_partitions[1]:
                write_files_to_ann(input_dir, input_dir + sub_dir + wsi_name, labels[i], output_dir, 'val.txt')
            elif wsi_name in wsi_partitions[2]:
                write_files_to_ann(input_dir, input_dir + sub_dir + wsi_name, labels[i], output_dir, 'test.txt')


def write_files_to_ann(root_dir, dir, label, output_dir, file):
    os.makedirs(output_dir, exist_ok=True)
    image_files = list()
    for img in os.listdir(dir):
        if os.path.splitext(img)[1].lower() in ['.jpg', '.jpeg', '.png', '.gif']:
            image_files.append((os.path.relpath(os.path.join(dir, img), root_dir), label))
        
    with open(os.path.join(output_dir, file), 'a') as w_file:
        for image_file, category in image_files:
            w_file.write(f"{image_file} {category}\n")

main()

# %% [markdown]
# # 查看w1标注信息

# %%
import os
import numpy as np
import json

DATA_ROOT = "D:/Dataset/"
config_name = '../../settings/environment.json'
if os.path.exists(config_name):
    with open(config_name, 'r') as file:
        info = json.load(file)
        DATA_ROOT = info["TCT_DATA_ROOT"]

ann_dir = DATA_ROOT+'TCT-NGC-2023/annotations/w1/'
files=['train.txt', 'val.txt', 'test.txt']

def info_ann(file_name):
    print(f"{file_name}中的各类WSI数量如下：")
    items = []
    with open(ann_dir+file_name, 'r') as file:
        for line in file:
            items.append(line.strip().split())
    
    labels = [int(data[1]) for data in items]
    max_label = max(labels)
    counts = np.zeros(max_label+2, dtype=np.uint32)
    
    # 统计标注为 -1 和 1 的个数
    for item in items:
        label = int(item[1])
        counts[label] += 1

    # 输出统计结果
    for i, count in enumerate(counts):
        if i == max_label+1:
            print('类别{:>2}: {:>6}'.format(-1, count))
        else:
            print('类别{:>2}: {:>6}'.format(i, count))
    print('全部  : {:>6}'.format(sum(counts)))
    return sum(counts)

def main():
    sum_all = 0    
    for file in files:
        sum_all += info_ann(file)
    print("  ")
    print('总和  : {:>6}'.format(sum_all))
main()
# Out:
# train.txt中的各类WSI数量如下：
# 类别 0:      0
# 类别 1: 240921
# 类别-1: 211569
# 全部  : 452490
# val.txt中的各类WSI数量如下：
# 类别 0:      0
# 类别 1:  34118
# 类别-1:  20670
# 全部  :  54788
# test.txt中的各类WSI数量如下：
# 类别 0:      0
# 类别 1:  32091
# 类别-1:  26351
# 全部  :  58442
#
# 总和  : 565720
